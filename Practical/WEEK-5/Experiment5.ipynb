# %% [markdown]
# <a href="https://colab.research.google.com/github/nehareddyg261-collab/ML/blob/main/Practical/WEEK-5/Experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load dataset
df = pd.read_csv("/content/placement_predict_50k_adjusted (1).csv")

# Select only two numerical features
X = df[['CGPA', 'AptitudeTestScore']]

# Apply Min-Max Scaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Convert to DataFrame
scaled_df = pd.DataFrame(
    X_scaled,
    columns=['CGPA', 'AptitudeTestScore']
)

print("Original Data")
print(X.head())

print("\nAfter Min-Max Scaling")
print(scaled_df.head())
# Out:
# Original Data
#    CGPA  AptitudeTestScore
# 0  6.63               62.3
# 1  6.40               44.0
# 2  7.73               73.8
# 3  9.73              100.0
# 4  9.01               90.8
#
# After Min-Max Scaling
#        CGPA  AptitudeTestScore
# 0  0.438333           0.614125
# 1  0.400000           0.426817
# 2  0.621667           0.731832
# 3  0.955000           1.000000
# 4  0.835000           0.905834
